# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Read corpus from user input
corpus = input("Enter the corpus: ")

comment_words = ''
stopwords = set(STOPWORDS)

# Split the input corpus into tokens
tokens = corpus.split()

# Convert each token into lowercase
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()

comment_words = " ".join(tokens)

wordcloud = WordCloud(width=800, height=800,
                      background_color='white',

                      min_font_size=10).generate(comment_words)

# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
# Out:
# Enter the corpus: Lulu was out for her usual morning walk when she took a wrong turn and found herself in the woods. She tried to retrace her steps, but soon realized she was lost. She began to panic, but then she remembered her training and started using her nose to sniff out a way home. She met all kinds of creatures along the way, but she was too scared to speak to them. Eventually, her nose led her to a house made of dog treats. It looked delicious, but she knew better than to eat anything she found in the woods. Suddenly, an evil witch appeared and tried to trap Lulu in the house. But Lulu was too smart for her and used her nose to find the door and escape. She was finally home safe and sound, and she vowed never to wander off the path again.

# %%
from collections import Counter

# %%
from collections import Counter
word_freq = Counter(corpus.split())
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# English: 7
# is: 3
# a: 2
# very: 1
# popular: 1
# language: 2
# that: 1
# spoken: 1
# all: 1
# around: 1
# the: 2
# world.: 1
# To: 1
# communicate: 1
# effectively: 1
# in: 2
# English,: 1
# it: 1
# important: 1
# to: 4
# have: 1
# strong: 1
# reading: 3
# comprehension: 1
# skills.: 1
# These: 2
# skills: 2
# will: 2
# allow: 1
# you: 2
# read: 1
# newspapers,: 1
# vocabulary: 1
# books,: 1
# and: 2
# novels!: 1
# This: 1
# blog: 1
# provides: 1
# readers: 1
# with: 2
# paragraphs: 1
# for: 1
# reading,: 1
# followed: 1
# by: 1
# practice: 1
# exercises: 1
# test: 1
# their: 1
# comprehension.: 1
# short: 2
# stories: 1
# are: 1
# designed: 1
# student: 1
# mind.: 1
# By: 1
# doing: 1
# these: 1
# passages: 1
# of: 1
# practice,: 1
# be: 1
# able: 1
# improve: 1
# your: 1
# better: 1
# understand: 1
# language.: 1

# %%
# Python program to generate WordCloud
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# Read corpus from user input
#corpus = input("Enter the corpus: ")
comment_words = ''
# stopwords = set(STOPWORDS);
stopwords = 'the and to in of with a for on as by'
# Split the input corpus into tokens
tokens = stopwords.split()

# Convert each token into lowercase
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()

comment_words = " ".join(tokens)

wordcloud = WordCloud(width=800, height=800,
                      background_color='white',

                      min_font_size=10).generate(comment_words)
# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
word_fre=Counter(corpus.split());
for word,fre in word_fre.items():
  print(f"{word}: {fre}")
# Out:
# Lulu: 3
# was: 5
# out: 2
# for: 2
# her: 8
# usual: 1
# morning: 1
# walk: 1
# when: 1
# she: 7
# took: 1
# a: 3
# wrong: 1
# turn: 1
# and: 7
# found: 2
# herself: 1
# in: 3
# the: 6
# woods.: 2
# She: 4
# tried: 2
# to: 10
# retrace: 1
# steps,: 1
# but: 4
# soon: 1
# realized: 1
# lost.: 1
# began: 1
# panic,: 1
# then: 1
# remembered: 1
# training: 1
# started: 1
# using: 1
# nose: 3
# sniff: 1
# way: 1
# home.: 1
# met: 1
# all: 1
# kinds: 1
# of: 2
# creatures: 1
# along: 1
# way,: 1
# too: 2
# scared: 1
# speak: 1
# them.: 1
# Eventually,: 1
# led: 1
# house: 1
# made: 1
# dog: 1
# treats.: 1
# It: 1
# looked: 1
# delicious,: 1
# knew: 1
# better: 1
# than: 1
# eat: 1
# anything: 1
# Suddenly,: 1
# an: 1
# evil: 1
# witch: 1
# appeared: 1
# trap: 1
# house.: 1
# But: 1
# smart: 1
# used: 1
# find: 1
# door: 1
# escape.: 1
# finally: 1
# home: 1
# safe: 1
# sound,: 1
# vowed: 1
# never: 1
# wander: 1
# off: 1
# path: 1
# again.: 1
